# %%
# Converting R to Python for file 1

# %%
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(1)

X = np.random.normal(size=1000)
Y = np.random.normal(size=1000)

# %%
ys = np.append(np.tile(1, 1000), np.tile(-1, 1000))
ys
# Out:
# array([ 1,  1,  1, ..., -1, -1, -1])

# %%
ys_color = np.append(np.tile("red", 1000), np.tile("green", 1000))
ys_color
# Out:
# array(['red', 'red', 'red', ..., 'green', 'green', 'green'], dtype='<U5')

# %%
import pandas as pd
data = pd.DataFrame({'X':X, 'Y':Y, "Z": X+Y>0})
data.head()
# Out:
#           X         Y      Z
# 0  1.624345 -0.153236   True
# 1 -0.611756 -2.432509  False
# 2 -0.528172  0.507984  False
# 3 -1.072969 -0.324032  False
# 4  0.865408 -1.511077  False

# %%
x_model = data.iloc[:,:2]
y_model = data.iloc[:,-1]

from sklearn import svm
# SVM regularization parameter
svc_classifier = svm.SVC(kernel='linear', C=0.1)
svc = svc_classifier.fit(x_model, y_model)

# %%
# mlxtend is a package built over matplotlib that
# abstracts the complexity of plotting and analysing
# algorithms

from mlxtend.plotting import plot_decision_regions
t = np.array(y_model)
t = t.astype(np.integer)

plt.figure(figsize = [15,10])
plot_decision_regions(np.array(x_model), t, clf = svc, hide_spines = False, colors = 'purple,limegreen',
                      markers = ['^','v'])
plt.title('Support Vector Machines')
# Out:
# C:\Users\devsh\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   import sys
# C:\Users\devsh\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"
# Text(0.5, 1.0, 'Support Vector Machines')

# %%
# SVM regularization parameter
svc_classifier_2 = svm.SVC(kernel='linear', C=10)
svc_2 = svc_classifier_2.fit(x_model, y_model)

# %%
plt.figure(figsize = [15,10])
plot_decision_regions(np.array(x_model), t, clf = svc_2, hide_spines = False, colors = 'orange,blue',
                      markers = ['^','v'])
plt.title('Support Vector Machines')
# Out:
# C:\Users\devsh\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"
# Text(0.5, 1.0, 'Support Vector Machines')

# %%
# cost function doesn't make a lot of difference in my case because
# the range of random values is minute.

# though a few points closer to the dividing axis has changed,
# obvious differences are minimum
